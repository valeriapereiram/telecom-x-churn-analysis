# %% [markdown]
# 🔹 Célula 1 – Importar e ler os dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json"
df = pd.read_json(url)

# %% [markdown]
# 🔹 Célula 2 – Explorar o dado bruto

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# 🔹 Célula 3 – Normalizar o JSON

# %%
df_normalizado = pd.json_normalize(df.to_dict(orient="records"))

# %% [markdown]
# 🔹 Célula 4 – Ajustar nomes das colunas

# %%
df_normalizado.columns = df_normalizado.columns.str.replace('.', '_')

# %% [markdown]
# 🔹 Célula 5 – Converter Charges Total (a que você achou que faltava)

# %%
df_normalizado['account_Charges_Total'] = pd.to_numeric(
    df_normalizado['account_Charges_Total'],
    errors='coerce'
)

# %% [markdown]
# 🔹 Célula 6 – Verificar valores nulos

# %%
df_normalizado.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer_gender               0
# customer_SeniorCitizen        0
# customer_Partner              0
# customer_Dependents           0
# customer_tenure               0
# phone_PhoneService            0
# phone_MultipleLines           0
# internet_InternetService      0
# internet_OnlineSecurity       0
# internet_OnlineBackup         0
# internet_DeviceProtection     0
# internet_TechSupport          0
# internet_StreamingTV          0
# internet_StreamingMovies      0
# account_Contract              0
# account_PaperlessBilling      0
# account_PaymentMethod         0
# account_Charges_Monthly       0
# account_Charges_Total        11
# dtype: int64

# %% [markdown]
# 🔹 Célula 7 – Converter Churn para numérico

# %%
df_normalizado['Churn'] = df_normalizado['Churn'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# 🔹 Célula 8 – Análise exploratória (EDA)

# %% [markdown]
# ## Análise exploratória
#
# Nesta etapa, foram realizadas análises iniciais para entender o comportamento
# do churn em relação a algumas variáveis dos clientes.

# %%
df_normalizado['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# 0.0    73.463013
# 1.0    26.536987
# Name: proportion, dtype: float64

# %% [markdown]
# 🔹 Célula 9 – Insights iniciais

# %% [markdown]
# ## Principais insights
#
# - A taxa de churn representa uma parcela significativa da base de clientes.
# - Clientes com menor tempo de permanência tendem a cancelar mais.
# - Contratos mensais apresentam maior risco de churn.

# %% [markdown]
# 🔹 Célula 10 – Conclusão

# %% [markdown]
# ## Conclusão
#
# O processo de ETL permitiu transformar dados brutos em um dataset estruturado,
# pronto para análises. A partir das análises iniciais, foi possível identificar
# padrões relevantes relacionados ao churn, que podem auxiliar em estratégias de
# retenção de clientes.
